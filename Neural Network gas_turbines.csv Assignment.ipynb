# %%
import pandas as pd
import numpy as np
import keras
import tensorflow
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
df=pd.read_csv("gas_turbines.csv")
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
df=df.iloc[:,[7,0,1,2]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TEY     15039 non-null  float64
#  1   AT      15039 non-null  float64
#  2   AP      15039 non-null  float64
#  3   AH      15039 non-null  float64
# dtypes: float64(4)
# memory usage: 470.1 KB

# %%
df.isna().sum()
# Out:
# TEY    0
# AT     0
# AP     0
# AH     0
# dtype: int64

# %%
df.shape
# Out:
# (15039, 4)

# %%
df.describe()
# Out:
#                 TEY            AT           AP            AH
# count  15039.000000  15039.000000  15039.00000  15039.000000
# mean     134.188464     17.764381   1013.19924     79.124174
# std       15.829717      7.574323      6.41076     13.793439
# min      100.170000      0.522300    985.85000     30.344000
# 25%      127.985000     11.408000   1008.90000     69.750000
# 50%      133.780000     18.186000   1012.80000     82.266000
# 75%      140.895000     23.862500   1016.90000     90.043500
# max      174.610000     34.929000   1034.20000    100.200000

# %%
x=df.iloc[:,1:5]
y=df.iloc[:,0]
x
# Out:
#            AT      AP      AH
# 0      6.8594  1007.9  96.799
# 1      6.7850  1008.4  97.118
# 2      6.8977  1008.8  95.939
# 3      7.0569  1009.2  95.249
# 4      7.3978  1009.7  95.150
# ...       ...     ...     ...
# 15034  9.0301  1005.6  98.460
# 15035  7.8879  1005.9  99.093
# 15036  7.2647  1006.3  99.496
# 15037  7.0060  1006.8  99.008
# 15038  6.9279  1007.2  97.533
#
# [15039 rows x 3 columns]

# %%
y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
from keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
seed = 7
np.random.seed(seed)
model = Sequential()
model.add(Dense(12, input_dim=3,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(8,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(1,  kernel_initializer='uniform', activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history= model.fit(x, y,validation_split=0.33, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 1008/1008 [==============================] - 4s 3ms/step - loss: -1716509.0000 - accuracy: 0.0000e+00 - val_loss: -6646822.0000 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -23036156.0000 - accuracy: 0.0000e+00 - val_loss: -45197928.0000 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -85258200.0000 - accuracy: 0.0000e+00 - val_loss: -129553512.0000 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -198214544.0000 - accuracy: 0.0000e+00 - val_loss: -266674688.0000 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -368090336.0000 - accuracy: 0.0000e+00 - val_loss: -462124736.0000 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -600668032.0000 - accuracy: 0.0000e+00 - val_loss: -721581568.0000 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -901865408.0000 - accuracy: 0.0000e+00 - val_loss: -1050913152.0000 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -1277554944.0000 - accuracy: 0.0000e+00 - val_loss: -1455913600.0000 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -1733984896.0000 - accuracy: 0.0000e+00 - val_loss: -1942753792.0000 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2277212672.0000 - accuracy: 0.0000e+00 - val_loss: -2517107456.0000 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2913630208.0000 - accuracy: 0.0000e+00 - val_loss: -3185682432.0000 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3649097472.0000 - accuracy: 0.0000e+00 - val_loss: -3953492736.0000 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 1008/1008 [==============================] - 3s 3ms/step - loss:
150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2571205607424.0000 - accuracy: 0.0000e+00 - val_loss: -2535939637248.0000 - val_accuracy: 0.0000e+00
# Epoch 134/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2627016065024.0000 - accuracy: 0.0000e+00 - val_loss: -2590783569920.0000 - val_accuracy: 0.0000e+00
# Epoch 135/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2683641266176.0000 - accuracy: 0.0000e+00 - val_loss: -2646432022528.0000 - val_accuracy: 0.0000e+00
# Epoch 136/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2741063647232.0000 - accuracy: 0.0000e+00 - val_loss: -2702826799104.0000 - val_accuracy: 0.0000e+00
# Epoch 137/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2799279013888.0000 - accuracy: 0.0000e+00 - val_loss: -2760048115712.0000 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2858314629120.0000 - accuracy: 0.0000e+00 - val_loss: -2818045378560.0000 - val_accuracy: 0.0000e+00
# Epoch 139/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2918164201472.0000 - accuracy: 0.0000e+00 - val_loss: -2876836413440.0000 - val_accuracy: 0.0000e+00
# Epoch 140/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2978817507328.0000 - accuracy: 0.0000e+00 - val_loss: -2936423841792.0000 - val_accuracy: 0.0000e+00
# Epoch 141/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3040341131264.0000 - accuracy: 0.0000e+00 - val_loss: -2996867432448.0000 - val_accuracy: 0.0000e+00
# Epoch 142/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3102692605952.0000 - accuracy: 0.0000e+00 - val_loss: -3058111610880.0000 - val_accuracy: 0.0000e+00
# Epoch 143/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3165867999232.0000 - accuracy: 0.0000e+00 - val_loss: -3120164241408.0000 - val_accuracy: 0.0000e+00
# Epoch 144/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -3229887758336.0000 - accuracy: 0.0000e+00 - val_loss: -3183033712640.0000 - val_accuracy: 0.0000e+00
# Epoch 145/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3294747688960.0000 - accuracy: 0.0000e+00 - val_loss: -3246734704640.0000 - val_accuracy: 0.0000e+00
# Epoch 146/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3360458014720.0000 - accuracy: 0.0000e+00 - val_loss: -3311287926784.0000 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3427036037120.0000 - accuracy: 0.0000e+00 - val_loss: -3376680271872.0000 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3494528679936.0000 - accuracy: 0.0000e+00 - val_loss: -3442964955136.0000 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3562889019392.0000 - accuracy: 0.0000e+00 - val_loss: -3510080897024.0000 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3632105783296.0000 - accuracy: 0.0000e+00 - val_loss: -3578042515456.0000 - val_accuracy: 0.0000e+00

# %%
scores = model.evaluate(x, y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 470/470 [==============================] - 1s 1ms/step - loss: -3637678702592.0000 - accuracy: 0.0000e+00
# accuracy: 0.00%

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
a = StandardScaler()
a.fit(x)
X_standardized = a.transform(x)
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2
# count  1.503900e+04  1.503900e+04  1.503900e+04
# mean  -2.320107e-16 -1.925280e-14  1.844983e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00
# min   -2.276462e+00 -4.266288e+00 -3.536594e+00
# 25%   -8.392292e-01 -6.706510e-01 -6.796337e-01
# 50%    5.566605e-02 -6.227861e-02  2.277844e-01
# 75%    8.051309e-01  5.772924e-01  7.916582e-01
# max    2.266234e+00  3.275970e+00  1.528011e+00

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=3, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))\
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam,RMSprop
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# C:\Users\prabi\AppData\Local\Temp\ipykernel_13264\436786627.py:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  20.6s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  19.5s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  18.6s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  18.6s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  18.2s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time= 1.5min
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time= 1.4min
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time= 1.4min
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time= 1.4min
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time= 1.5min
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 3.1min
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 3.0min
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 3.4min
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 2.8min
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 2.9min
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=  10.1s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   9.6s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   9.6s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   9.7s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   9.5s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  43.8s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  44.6s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  43.7s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  44.0s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  43.5s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.4min
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.6min
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.8min
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.5min
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.5min
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   5.6s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   5.6s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   5.5s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   5.5s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   6.4s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  26.1s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  27.9s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  26.7s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  27.1s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  26.4s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  44.8s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  45.4s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  45.8s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  45.7s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  45.2s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'batch_size': 10, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 100}

# %%
def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 3,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 3,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# C:\Users\prabi\AppData\Local\Temp\ipykernel_13264\2157490907.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   8.7s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   6.1s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   6.2s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   7.1s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   6.5s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   6.5s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   6.2s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   6.6s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   6.2s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   6.1s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   6.0s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 2/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   6.9s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   7.6s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   6.5s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   6.2s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   6.6s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   5.9s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   5.8s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   5.8s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   6.1s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   6.0s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   6.2s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   6.0s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   7.1s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   6.7s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   6.3s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   5.9s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   6.1s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   5.8s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   5.9s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   6.0s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   6.8s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   5.9s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   6.4s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   5.9s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   6.4s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   6.0s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   5.9s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   6.3s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   6.6s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   5.8s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   5.9s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   5.9s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   5.8s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   5.8s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   6.2s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   6.3s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   6.2s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   5.9s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   5.9s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   5.8s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   6.4s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   6.6s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   5.8s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   5.8s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   5.8s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   5.8s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   5.8s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   6.1s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   5.9s

# %%
def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 3,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# C:\Users\prabi\AppData\Local\Temp\ipykernel_13264\1166029089.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   6.4s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   6.0s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   6.1s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   6.0s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   5.9s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   5.9s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   5.9s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   5.9s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   5.9s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   5.8s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   6.3s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   5.9s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   6.0s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   6.0s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   5.9s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   6.0s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   5.9s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   5.9s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   5.9s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   5.9s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   5.9s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   6.3s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   6.0s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   6.1s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   5.9s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.0s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.0s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.0s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.0s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.0s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   6.0s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   6.0s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   5.9s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   6.4s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   6.0s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   6.1s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   7.4s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   6.3s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   6.1s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   6.1s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   6.1s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   6.1s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   6.2s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   6.0s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   5.9s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 8}

# %%
from sklearn.metrics import classification_report, accuracy_score
def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(8,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'linear'))
    
    adam = Adam(lr = 0.01) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y_predict.round(),y.round()))
# Out:
# C:\Users\prabi\AppData\Local\Temp\ipykernel_13264\4133789037.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 470/470 [==============================] - 1s 1ms/step
# 0.00013298756566261055
